# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/SyntaxSquad/datasets
# !ls

# %%
# !pip install -q clearml
# %env CLEARML_WEB_HOST=https://app.clear.ml/
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=CLEARML_API_ACCESS_KEY
# %env CLEARML_API_SECRET_KEY=CLEARML_API_SECRET_KEY
# %env MPLBACKEND=tkagg

# %%
# !clearml-data create --project SyntaxSquad --name WLASL2000
# !clearml-data add --files wlasl-processed.zip wlasl2000-resized.zip
# !clearml-data close
# Out:
# clearml-data - Dataset Management & Versioning CLI
# Creating a new dataset:
# ClearML results page: https://app.clear.ml/projects/7b4b2a99e12c49f4b17cb819db28e1a8/experiments/921fdb13ed94464ebcf0dd0586856a5c/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/7b4b2a99e12c49f4b17cb819db28e1a8/experiments/921fdb13ed94464ebcf0dd0586856a5c
# New dataset created id=921fdb13ed94464ebcf0dd0586856a5c
# clearml-data - Dataset Management & Versioning CLI
# Adding files/folder/links to dataset id 921fdb13ed94464ebcf0dd0586856a5c
# 2 files added
# clearml-data - Dataset Management & Versioning CLI
# Finalizing dataset id 921fdb13ed94464ebcf0dd0586856a5c
# Pending uploads, starting dataset upload to https://files.clear.ml
# Uploading dataset changes (1 files compressed to 1.87 GiB) to https://files.clear.ml
# Uploading dataset changes (1 files compressed to 4.82 GiB) to https://files.clear.ml
# ...

# %%
from clearml import Dataset
wlasl_path = Dataset.get(dataset_id='921fdb13ed94464ebcf0dd0586856a5c').get_local_copy()
# !ls {wlasl_path}
# Out:
# 2025-04-14 16:19:20,271 - clearml.storage - INFO - Downloading: 1913.61MB from https://files.clear.ml/SyntaxSquad/.datasets/WLASL2000/WLASL2000.921fdb13ed94464ebcf0dd0586856a5c/artifacts/data/dataset.921fdb13ed94464ebcf0dd0586856a5c.qzp7we_h.zip
# █████████████████████████▉ 100% | 1905.00/1913.61 MB [00:17<00:00, 127.33MB/s]: /usr/local/lib/python3.11/dist-packages/tqdm/std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# ██████████████████████████ 100% | 1913.61/1913.61 MB [00:17<00:00, 111.52MB/s]:
# 2025-04-14 16:19:37,440 - clearml.storage - INFO - Downloaded 1913.61 MB successfully from https://files.clear.ml/SyntaxSquad/.datasets/WLASL2000/WLASL2000.921fdb13ed94464ebcf0dd0586856a5c/artifacts/data/dataset.921fdb13ed94464ebcf0dd0586856a5c.qzp7we_h.zip , saved to /root/.clearml/cache/storage_manager/datasets/0fb5432b93e70e811c006eda7c34201a.dataset.921fdb13ed94464ebcf0dd0586856a5c.qzp7we_h.zip
# ...

# %%
# !clearml-data create --project SyntaxSquad --name WLASL2000 --parents 921fdb13ed94464ebcf0dd0586856a5c
# !clearml-data add --files WLASL_landmarks.npz WLASL_parsed_metadata.json
# !clearml-data close
# Out:
# clearml-data - Dataset Management & Versioning CLI
# Creating a new dataset:
# ClearML results page: https://app.clear.ml/projects/7b4b2a99e12c49f4b17cb819db28e1a8/experiments/3b222a4667044677b2f7bc0a628ea9f4/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/7b4b2a99e12c49f4b17cb819db28e1a8/experiments/3b222a4667044677b2f7bc0a628ea9f4
# New dataset created id=3b222a4667044677b2f7bc0a628ea9f4
# clearml-data - Dataset Management & Versioning CLI
# Adding files/folder/links to dataset id 3b222a4667044677b2f7bc0a628ea9f4
# 2 files added
# clearml-data - Dataset Management & Versioning CLI
# Finalizing dataset id 3b222a4667044677b2f7bc0a628ea9f4
# Pending uploads, starting dataset upload to https://files.clear.ml
# Uploading dataset changes (1 files compressed to 2.5 GiB) to https://files.clear.ml
# Uploading dataset changes (1 files compressed to 217.88 KiB) to https://files.clear.ml
# ...
